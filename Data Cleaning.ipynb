# %% [markdown]
# # Question Answer LLM

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Preprocessing & Cleaning data
#
# Data Source: https://www.kaggle.com/datasets/trainingdatapro/sat-history-questions-and-answers/

# %%
df = pd.read_csv("/content/sat_world_and_us_history.csv")

# %%
df.head()
# Out:
#    id        subject  \
# 0   1  world_history
# 1   2  world_history
# 2   3  world_history
# 3   4  world_history
# 4   5  world_history
#
#                                                                                   prompt  \
# 0                       Sumer and Egypt were similar in all of the following ways EXCEPT
# 1  A follower of the Chinese philosophy of Daoism would MOST agree with which statement?
# 2        Which of these was NOT a characteristic of early humans in the Paleolithic Age?
# 3             Buddhism was founded in part as a response to questions about which faith?
# 4      The Kush city of Meroe rose to prominence mainly because of its natural supply of
#
#                                                              A  \
# 0  agricultural dependence on the silt left behind by flooding
# 1        Government intrusiveness should be kept to a minimum.
# 2                         Ability to make and use simple tools
# 3                                                        Islam
# 4                                                         salt
#
#                                                                  B  \
# 0  belief in a polytheistic religion centered on deities of nature
# 1             Government works best when run by well-educated men.
# 2                        Tendency to live in permanent settlements
# 3                                                           Daoism
# 4                                                             iron
#
#                                                            C  \
# 0  enjoyment of protection from invasion by natural barriers
# 1   Government should be focused on strengthening the state.
# 2               Reliance on hunting and gathering techniques
# 3                                                    Judaism
# 4                                                       gold
#
#                                                              D  \
# 0          development of distinct systems of written language
# 1  Governments that allow too much freedom are doomed to fail.
# 2               Propensity for creating artistic cave drawings
# 3                                                     Hinduism
# 4                                                        grain
#
#                                                                  E answer
# 0                   engagement in trade with other nearby cultures      C
# 1  Governments have an obligation to suppress independent thought.      A
# 2                 Mastery of fire for cooking and heating purposes      B
# 3                                                     Christianity      D
# 4                                                           silver      B

# %%
example = df.loc[0]

# %%
example[example["answer"]]
# Out:
# 'enjoyment of protection from invasion by natural barriers'

# %%
df["answer"].unique()
# Out:
# array(['C', 'A', 'B', 'D', 'E', 'A.', 'D.', 'E.', 'B.', 'C.', '.',
#        'A. (A)   the replacement of political machines with more efficient and professional forms of municipal government.\nB. federal projects to divert rivers and build levees.\nC. people to abandon seaside cities and move to higher elevations.\nD. a federal income tax.\nE. a religious reawakening to allay fears of divine punishment.\n A\nExplanation: \nThe political machine in Galveston was unable to deal with the crisis at hand, and many reformers saw this as evidence that these machines had outlived their usefulness. Calls for federal projects are associated with the New Deal. Abandoning seaside communities never occurred in any significant way. A federal income tax was instituted in 1913 with the passage of the 16th Amendment after protectionist tariffs were reduced. A religious awakening did not occur as a result of the hurricane.\nPrevious\xa0\xa0\xa0\xa0\xa0\xa0\xa0Next'],
#       dtype=object)

# %%
df["answer"] = df["answer"].str.replace(".","")
# Out:
# <ipython-input-104-5228974aa5f4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["answer"] = df["answer"].str.replace(".","")

# %%
df[df["answer"] == ""] #188
# Out:
#       id        subject  \
# 188  198  world_history
#
#                                                                                   prompt  \
# 188  In 1935, Italian forces under the command of Benito Mussolini invaded the nation of
#
#            A         B      C      D        E answer
# 188  Somalia  Ethiopia  Egypt  Libya  Nigeria

# %%
df["answer"].unique()
# Out:
# array(['C', 'A', 'B', 'D', 'E', '',
#        'A (A)   the replacement of political machines with more efficient and professional forms of municipal government\nB federal projects to divert rivers and build levees\nC people to abandon seaside cities and move to higher elevations\nD a federal income tax\nE a religious reawakening to allay fears of divine punishment\n A\nExplanation: \nThe political machine in Galveston was unable to deal with the crisis at hand, and many reformers saw this as evidence that these machines had outlived their usefulness Calls for federal projects are associated with the New Deal Abandoning seaside communities never occurred in any significant way A federal income tax was instituted in 1913 with the passage of the 16th Amendment after protectionist tariffs were reduced A religious awakening did not occur as a result of the hurricane\nPrevious\xa0\xa0\xa0\xa0\xa0\xa0\xa0Next'],
#       dtype=object)

# %%
outlier = 'A (A)   the replacement of political machines with more efficient and professional forms of municipal government\nB federal projects to divert rivers and build levees\nC people to abandon seaside cities and move to higher elevations\nD a federal income tax\nE a religious reawakening to allay fears of divine punishment\n A\nExplanation: \nThe political machine in Galveston was unable to deal with the crisis at hand, and many reformers saw this as evidence that these machines had outlived their usefulness Calls for federal projects are associated with the New Deal Abandoning seaside communities never occurred in any significant way A federal income tax was instituted in 1913 with the passage of the 16th Amendment after protectionist tariffs were reduced A religious awakening did not occur as a result of the hurricane\nPrevious\xa0\xa0\xa0\xa0\xa0\xa0\xa0Next'

# %%
df[df["answer"] == 'A (A)   the replacement of political machines with more efficient and professional forms of municipal government\nB federal projects to divert rivers and build levees\nC people to abandon seaside cities and move to higher elevations\nD a federal income tax\nE a religious reawakening to allay fears of divine punishment\n A\nExplanation: \nThe political machine in Galveston was unable to deal with the crisis at hand, and many reformers saw this as evidence that these machines had outlived their usefulness Calls for federal projects are associated with the New Deal Abandoning seaside communities never occurred in any significant way A federal income tax was instituted in 1913 with the passage of the 16th Amendment after protectionist tariffs were reduced A religious awakening did not occur as a result of the hurricane\nPrevious\xa0\xa0\xa0\xa0\xa0\xa0\xa0Next']
# Out:
#         id     subject  \
# 1316  1082  us_history
#
#                                                                                              prompt  \
# 1316  The devastation caused by a hurricane and flood in Galveston, Texas, in 1900 led to calls for
#
#                                                                                                                     A  \
# 1316  (A)   the replacement of political machines with more efficient and professional forms of municipal government.
#
#                                                         B  \
# 1316  federal projects to divert rivers and build levees.
#
#                                                                     C  \
# 1316  people to abandon seaside cities and move to higher elevations.
#
#                           D  \
# 1316  a federal income tax.
#
#                                                                  E  \
# 1316  a religious reawakening to allay fears of divine punishment.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                answer
# 1316  A (A)   the replacement of political machines with more efficient and professional forms of municipal government\nB federal projects to divert rivers and build levees\nC people to abandon seaside cities and move to higher elevations\nD a federal income tax\nE a religious reawakening to allay fears of divine punishment\n A\nExplanation: \nThe political machine in Galveston was unable to deal with the crisis at hand, and many reformers saw this as evidence that these machines had outlived their usefulness Calls for federal projects are associated with the New Deal Abandoning seaside communities never occurred in any significant way A federal income tax was instituted in 1913 with the passage of the 16th Amendment after protectionist tariffs were reduced A religious awakening did not occur as a result of the hurricane\nPrevious       Next

# %%
df.at[1316,'answer'] = "A"

# %%
df["answer"].unique()
# Out:
# array(['C', 'A', 'B', 'D', 'E', ''], dtype=object)

# %%
df[df["answer"] == ""]["prompt"]
# Out:
# 188    In 1935, Italian forces under the command of B...
# Name: prompt, dtype: object

# %%
df.at[188,'answer'] = "B"

# %%
# Hence we converted the answer column perfectly, Let's check if we have any other problem
df["answer"].unique()
# Out:
# array(['C', 'A', 'B', 'D', 'E'], dtype=object)

# %%
def correct_answer(example):
  return example[example["answer"]]

# %%
df_copy = df.head()

# %%
options = df[["A","B","C","D","E"]]

# %%
options.head()
# Out:
#                                                    A  \
# 0  agricultural dependence on the silt left behin...
# 1  Government intrusiveness should be kept to a m...
# 2               Ability to make and use simple tools
# 3                                              Islam
# 4                                               salt
#
#                                                    B  \
# 0  belief in a polytheistic religion centered on ...
# 1  Government works best when run by well-educate...
# 2          Tendency to live in permanent settlements
# 3                                             Daoism
# 4                                               iron
#
#                                                    C  \
# 0  enjoyment of protection from invasion by natur...
# 1  Government should be focused on strengthening ...
# 2       Reliance on hunting and gathering techniques
# 3                                            Judaism
# 4                                               gold
#
#                                                    D  \
# 0  development of distinct systems of written lan...
# 1  Governments that allow too much freedom are do...
# 2     Propensity for creating artistic cave drawings
# 3                                           Hinduism
# 4                                              grain
#
#                                                    E
# 0     engagement in trade with other nearby cultures
# 1  Governments have an obligation to suppress ind...
# 2   Mastery of fire for cooking and heating purposes
# 3                                       Christianity
# 4                                             silver

# %%
df.head()
# Out:
#    id        subject                                             prompt  \
# 0   1  world_history  Sumer and Egypt were similar in all of the fol...
# 1   2  world_history  A follower of the Chinese philosophy of Daoism...
# 2   3  world_history  Which of these was NOT a characteristic of ear...
# 3   4  world_history  Buddhism was founded in part as a response to ...
# 4   5  world_history  The Kush city of Meroe rose to prominence main...
#
#                                                    A  \
# 0  agricultural dependence on the silt left behin...
# 1  Government intrusiveness should be kept to a m...
# 2               Ability to make and use simple tools
# 3                                              Islam
# 4                                               salt
#
#                                                    B  \
# 0  belief in a polytheistic religion centered on ...
# 1  Government works best when run by well-educate...
# 2          Tendency to live in permanent settlements
# 3                                             Daoism
# 4                                               iron
#
#                                                    C  \
# 0  enjoyment of protection from invasion by natur...
# 1  Government should be focused on strengthening ...
# 2       Reliance on hunting and gathering techniques
# 3                                            Judaism
# 4                                               gold
#
#                                                    D  \
# 0  development of distinct systems of written lan...
# 1  Governments that allow too much freedom are do...
# 2     Propensity for creating artistic cave drawings
# 3                                           Hinduism
# 4                                              grain
#
#                                                    E answer
# 0     engagement in trade with other nearby cultures      C
# 1  Governments have an obligation to suppress ind...      A
# 2   Mastery of fire for cooking and heating purposes      B
# 3                                       Christianity      D
# 4                                             silver      B

# %%
# index, column_name
copy = df.head()

# %%
copy
# Out:
#    id        subject                                             prompt  \
# 0   1  world_history  Sumer and Egypt were similar in all of the fol...
# 1   2  world_history  A follower of the Chinese philosophy of Daoism...
# 2   3  world_history  Which of these was NOT a characteristic of ear...
# 3   4  world_history  Buddhism was founded in part as a response to ...
# 4   5  world_history  The Kush city of Meroe rose to prominence main...
#
#                                                    A  \
# 0  agricultural dependence on the silt left behin...
# 1  Government intrusiveness should be kept to a m...
# 2               Ability to make and use simple tools
# 3                                              Islam
# 4                                               salt
#
#                                                    B  \
# 0  belief in a polytheistic religion centered on ...
# 1  Government works best when run by well-educate...
# 2          Tendency to live in permanent settlements
# 3                                             Daoism
# 4                                               iron
#
#                                                    C  \
# 0  enjoyment of protection from invasion by natur...
# 1  Government should be focused on strengthening ...
# 2       Reliance on hunting and gathering techniques
# 3                                            Judaism
# 4                                               gold
#
#                                                    D  \
# 0  development of distinct systems of written lan...
# 1  Governments that allow too much freedom are do...
# 2     Propensity for creating artistic cave drawings
# 3                                           Hinduism
# 4                                              grain
#
#                                                    E answer
# 0     engagement in trade with other nearby cultures      C
# 1  Governments have an obligation to suppress ind...      A
# 2   Mastery of fire for cooking and heating purposes      B
# 3                                       Christianity      D
# 4                                             silver      B

# %%
for index, column_name in enumerate(copy["answer"]):
  copy.at[index, "correct_answer"] = copy[column_name].iloc[index]
# Out:
# <ipython-input-157-3d0b3fd85d31>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   copy.at[index, "correct_answer"] = copy[column_name].iloc[index]

# %%
copy
# Out:
#    id        subject                                             prompt  \
# 0   1  world_history  Sumer and Egypt were similar in all of the fol...
# 1   2  world_history  A follower of the Chinese philosophy of Daoism...
# 2   3  world_history  Which of these was NOT a characteristic of ear...
# 3   4  world_history  Buddhism was founded in part as a response to ...
# 4   5  world_history  The Kush city of Meroe rose to prominence main...
#
#                                                    A  \
# 0  agricultural dependence on the silt left behin...
# 1  Government intrusiveness should be kept to a m...
# 2               Ability to make and use simple tools
# 3                                              Islam
# 4                                               salt
#
#                                                    B  \
# 0  belief in a polytheistic religion centered on ...
# 1  Government works best when run by well-educate...
# 2          Tendency to live in permanent settlements
# 3                                             Daoism
# 4                                               iron
#
#                                                    C  \
# 0  enjoyment of protection from invasion by natur...
# 1  Government should be focused on strengthening ...
# 2       Reliance on hunting and gathering techniques
# 3                                            Judaism
# 4                                               gold
#
#                                                    D  \
# 0  development of distinct systems of written lan...
# 1  Governments that allow too much freedom are do...
# 2     Propensity for creating artistic cave drawings
# 3                                           Hinduism
# 4                                              grain
#
#                                                    E answer  \
# 0     engagement in trade with other nearby cultures      C
# 1  Governments have an obligation to suppress ind...      A
# 2   Mastery of fire for cooking and heating purposes      B
# 3                                       Christianity      D
# 4                                             silver      B
#
#                                       correct_answer
# 0  enjoyment of protection from invasion by natur...
# 1  Government intrusiveness should be kept to a m...
# 2          Tendency to live in permanent settlements
# 3                                           Hinduism
# 4                                               iron

# %%
for index, column_name in enumerate(df["answer"]):
  df.at[index, "correct_answer"] = df[column_name].iloc[index]

# %%
df.tail()
# Out:
#         id     subject                                             prompt  \
# 1375  1141  us_history       The Election of 2000 was significant because
# 1376  1142  us_history  In his 2001 "War on Terror" speech to Congress...
# 1377  1143  us_history                     Mortgage-backed securities are
# 1378  1144  us_history  George W. Bush's immigration reform policy can...
# 1379  1145  us_history                        The Bush Doctrine refers to
#
#                                                       A  \
# 1375  the Supreme Court of Florida decided the elect...
# 1376             immediately close all terrorist camps.
# 1377  bundles of subprime mortgages traded like stocks.
# 1378  amnesty for all people who immigrated to the U...
# 1379  a policy of unilateral, preemptive strikes aga...
#
#                                                       B  \
# 1375  Katherine Harris, a Democrat, validated the el...
# 1376                     release all foreign prisoners.
# 1377  low-interest loans offered to people with trou...
# 1378  unrealistic, in that it refused to acknowledge...
# 1379  a program of tax cuts to spark economic activity.
#
#                                                       C  \
# 1375  Al Gore won more popular votes than George W. ...
# 1376  transfer all terrorists on Afghani soil to the...
# 1377        another name for adjustable-rate mortgages.
# 1378  a policy to deport immediately all illegal imm...
# 1379  a policy of creating an international coalitio...
#
#                                                       D  \
# 1375  Jeb Bush, the brother of George W. Bush, was g...
# 1376                          hand over Saddam Hussein.
# 1377                       recession-proof investments.
# 1378  a pathway to citizenship for illegal immigrant...
# 1379  rebuilding the Gulf Coast after Hurricane Katr...
#
#                                                       E answer  \
# 1375  George W. Bush was the first son to follow his...      C
# 1376  give U.S. troops access to terror camps to ens...      D
# 1377                                     stable assets.      A
# 1378  a way to safeguard American jobs for U.S. citi...      D
# 1379  a systematic plan to encourage environmental i...      A
#
#                                          correct_answer
# 1375  Al Gore won more popular votes than George W. ...
# 1376                          hand over Saddam Hussein.
# 1377  bundles of subprime mortgages traded like stocks.
# 1378  a pathway to citizenship for illegal immigrant...
# 1379  a policy of unilateral, preemptive strikes aga...

# %%
df.drop(labels=["A","B","C","D","E","id","answer"],axis=1,inplace=True)
df.head()
# Out:
#          subject                                             prompt  \
# 0  world_history  Sumer and Egypt were similar in all of the fol...
# 1  world_history  A follower of the Chinese philosophy of Daoism...
# 2  world_history  Which of these was NOT a characteristic of ear...
# 3  world_history  Buddhism was founded in part as a response to ...
# 4  world_history  The Kush city of Meroe rose to prominence main...
#
#                                       correct_answer
# 0  enjoyment of protection from invasion by natur...
# 1  Government intrusiveness should be kept to a m...
# 2          Tendency to live in permanent settlements
# 3                                           Hinduism
# 4                                               iron

# %%
# Atlast We have preprocessed our data into question and answer format
df = df.rename(columns={"prompt":"question",
                   "correct_answer":"answer"})

# %%
df.head()
# Out:
#          subject                                           question  \
# 0  world_history  Sumer and Egypt were similar in all of the fol...
# 1  world_history  A follower of the Chinese philosophy of Daoism...
# 2  world_history  Which of these was NOT a characteristic of ear...
# 3  world_history  Buddhism was founded in part as a response to ...
# 4  world_history  The Kush city of Meroe rose to prominence main...
#
#                                               answer
# 0  enjoyment of protection from invasion by natur...
# 1  Government intrusiveness should be kept to a m...
# 2          Tendency to live in permanent settlements
# 3                                           Hinduism
# 4                                               iron

# %%
df.to_csv("/content/question_answer.csv")

# %% [markdown]
# ## Large Language Model

# %%
from langchain.llms import GooglePalm

api_key = "Enter your api_key"

llm = GooglePalm(google_api_key=api_key, temperature=0)

# %%
res = llm("Explain what are Large Language Models to a 5 year old")
print(res)
# Out:
# Imagine you have a big dictionary, and you can ask it questions about anything. It can tell you the meaning of words, the capital of countries, and even the answer to math problems. Now imagine that dictionary was also really good at understanding what you said, even if you didn't use perfect grammar. It could tell if you were asking a question or making a statement, and it could give you the right answer. That's what a large language model is like. It's a really big dictionary that can understand what you say and give you the right answer.

# %%
from langchain.chains import RetrievalQA


from langchain.embeddings import GooglePalmEmbeddings
from langchain.llms import GooglePalm

# %%
from langchain.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path='question_answer.csv', source_column="question")

# Store the loaded data in the 'data' variable
data = loader.load()

# %%
print(data[0])
# Out:
# page_content=': 0\nsubject: world_history\nquestion: Sumer and Egypt were similar in all of the following ways EXCEPT\nanswer: enjoyment of protection from invasion by natural barriers' metadata={'source': 'Sumer and Egypt were similar in all of the following ways EXCEPT', 'row': 0}
